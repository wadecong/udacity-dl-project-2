# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return np.array(x)/255


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
# map_of_encodings = None

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    global map_of_encodings
    
    if map_of_encodings is not None:
        rst = []
        for i in x:
            rst.append(map_of_encodings[i])
        return np.array(rst)
    
    from sklearn import preprocessing
    
    lb = preprocessing.LabelBinarizer()
    lb.fit(x)
    
    rst = np.array(lb.transform(x))
    
    for index in range(len(x)):
        map_of_encodings[x[index]] = rst[index]
    
    return rst


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)
print('saved!')
# Out:
# saved!

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    shapes = [None, image_shape[0], image_shape[1], image_shape[2]]
    return tf.placeholder(tf.float32, shape=shapes, name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=[None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], x_tensor.shape[3].value, conv_num_outputs]))

    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    conv_layer = tf.nn.conv2d(x_tensor, 
                              weight, 
                              strides=[1,conv_strides[0], conv_strides[1], 1], 
                              padding='SAME')
    
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    
    conv_layer = tf.nn.relu(conv_layer)
    
    conv_layer = tf.nn.max_pool(conv_layer, 
                                ksize=[1, pool_ksize[0], pool_ksize[1], 1],
                                strides=[1, pool_strides[0], pool_strides[1], 1],
                                padding='SAME')
    
    return conv_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(inputs=x_tensor, num_outputs=num_outputs, activation_fn=tf.nn.relu)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    return tf.contrib.layers.fully_connected(inputs=x_tensor, num_outputs=num_outputs, activation_fn=None)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)

    conv_layer = x
    conv_num_outputs = 64
    conv_ksize = (3, 3)
    conv_strides = (2, 2)
    pool_ksize = (3, 3)
    pool_strides = (2, 2)
    
    conv_layer = conv2d_maxpool(conv_layer, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    print(conv_layer)
    conv_layer = conv2d_maxpool(conv_layer, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    print(conv_layer)
    conv_layer = conv2d_maxpool(conv_layer, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    print(conv_layer)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    conv_layer = flatten(conv_layer)
    
    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    num_outputs = 64
    conv_layer = fully_conn(conv_layer, num_outputs)
    conv_layer = fully_conn(conv_layer, num_outputs)
    conv_layer = fully_conn(conv_layer, num_outputs)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    output_layer = output(conv_layer, 10)
    
    # TODO: return output
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Tensor("MaxPool:0", shape=(?, 8, 8, 64), dtype=float32)
# Tensor("MaxPool_1:0", shape=(?, 2, 2, 64), dtype=float32)
# Tensor("MaxPool_2:0", shape=(?, 1, 1, 64), dtype=float32)
# Tensor("MaxPool_3:0", shape=(?, 8, 8, 64), dtype=float32)
# Tensor("MaxPool_4:0", shape=(?, 2, 2, 64), dtype=float32)
# Tensor("MaxPool_5:0", shape=(?, 1, 1, 64), dtype=float32)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    return session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    current_cost = session.run(
        cost,
        feed_dict={x: feature_batch, y: label_batch})
    valid_accuracy = sess.run(
        accuracy,
        feed_dict={x: valid_features, y: valid_labels})
    print('Cost: {:<8.3} Valid Accuracy: {:<5.3}'.format(
        current_cost,
        valid_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 1024
keep_probability = .5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost: 38.3     Valid Accuracy: 0.188
# Epoch  2, CIFAR-10 Batch 1:  Cost: 16.4     Valid Accuracy: 0.209
# Epoch  3, CIFAR-10 Batch 1:  Cost: 14.2     Valid Accuracy: 0.227
# Epoch  4, CIFAR-10 Batch 1:  Cost: 9.68     Valid Accuracy: 0.226
# Epoch  5, CIFAR-10 Batch 1:  Cost: 7.77     Valid Accuracy: 0.242
# Epoch  6, CIFAR-10 Batch 1:  Cost: 6.33     Valid Accuracy: 0.243
# Epoch  7, CIFAR-10 Batch 1:  Cost: 5.6      Valid Accuracy: 0.253
# Epoch  8, CIFAR-10 Batch 1:  Cost: 4.97     Valid Accuracy: 0.251
# Epoch  9, CIFAR-10 Batch 1:  Cost: 4.6      Valid Accuracy: 0.259
# Epoch 10, CIFAR-10 Batch 1:  Cost: 4.2      Valid Accuracy: 0.259
# Epoch 11, CIFAR-10 Batch 1:  Cost: 3.86     Valid Accuracy: 0.263
# Epoch 12, CIFAR-10 Batch 1:  Cost: 3.63     Valid Accuracy: 0.262
# Epoch 13, CIFAR-10 Batch 1:  Cost: 3.41     Valid Accuracy: 0.262
# Epoch 14, CIFAR-10 Batch 1:  Cost: 3.2      Valid Accuracy: 0.263
# Epoch 15, CIFAR-10 Batch 1:  Cost: 3.0      Valid Accuracy: 0.267
# Epoch 16, CIFAR-10 Batch 1:  Cost: 2.85     Valid Accuracy: 0.27
# Epoch 17, CIFAR-10 Batch 1:  Cost: 2.72     Valid Accuracy: 0.269
# Epoch 18, CIFAR-10 Batch 1:  Cost: 2.62     Valid Accuracy: 0.275
# Epoch 19, CIFAR-10 Batch 1:  Cost: 2.52     Valid Accuracy: 0.276
# Epoch 20, CIFAR-10 Batch 1:  Cost: 2.42     Valid Accuracy: 0.276
# Epoch 21, CIFAR-10 Batch 1:  Cost: 2.33     Valid Accuracy: 0.278
# Epoch 22, CIFAR-10 Batch 1:  Cost: 2.25     Valid Accuracy: 0.279
# Epoch 23, CIFAR-10 Batch 1:  Cost: 2.19     Valid Accuracy: 0.284
# Epoch 24, CIFAR-10 Batch 1:  Cost: 2.13     Valid Accuracy: 0.285
# Epoch 25, CIFAR-10 Batch 1:  Cost: 2.09     Valid Accuracy: 0.285
# Epoch 26, CIFAR-10 Batch 1:  Cost: 2.05     Valid Accuracy: 0.287
# Epoch 27, CIFAR-10 Batch 1:  Cost: 2.0      Valid Accuracy: 0.293
# Epoch 28, CIFAR-10 Batch 1:  Cost: 1.96     Valid Accuracy: 0.295

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost: 45.8     Valid Accuracy: 0.19
# Epoch  1, CIFAR-10 Batch 2:  Cost: 26.7     Valid Accuracy: 0.206
# Epoch  1, CIFAR-10 Batch 3:  Cost: 18.5     Valid Accuracy: 0.195
# Epoch  1, CIFAR-10 Batch 4:  Cost: 11.6     Valid Accuracy: 0.188
# Epoch  1, CIFAR-10 Batch 5:  Cost: 8.94     Valid Accuracy: 0.212
# Epoch  2, CIFAR-10 Batch 1:  Cost: 7.47     Valid Accuracy: 0.238
# Epoch  2, CIFAR-10 Batch 2:  Cost: 6.47     Valid Accuracy: 0.233
# Epoch  2, CIFAR-10 Batch 3:  Cost: 5.98     Valid Accuracy: 0.238
# Epoch  2, CIFAR-10 Batch 4:  Cost: 5.18     Valid Accuracy: 0.247
# Epoch  2, CIFAR-10 Batch 5:  Cost: 4.78     Valid Accuracy: 0.252
# Epoch  3, CIFAR-10 Batch 1:  Cost: 4.35     Valid Accuracy: 0.257
# Epoch  3, CIFAR-10 Batch 2:  Cost: 3.86     Valid Accuracy: 0.261
# Epoch  3, CIFAR-10 Batch 3:  Cost: 3.63     Valid Accuracy: 0.248
# Epoch  3, CIFAR-10 Batch 4:  Cost: 3.26     Valid Accuracy: 0.267
# Epoch  3, CIFAR-10 Batch 5:  Cost: 3.18     Valid Accuracy: 0.265
# Epoch  4, CIFAR-10 Batch 1:  Cost: 2.99     Valid Accuracy: 0.268
# Epoch  4, CIFAR-10 Batch 2:  Cost: 2.85     Valid Accuracy: 0.273
# Epoch  4, CIFAR-10 Batch 3:  Cost: 2.6      Valid Accuracy: 0.29
# Epoch  4, CIFAR-10 Batch 4:  Cost: 2.47     Valid Accuracy: 0.284
# Epoch  4, CIFAR-10 Batch 5:  Cost: 2.62     Valid Accuracy: 0.274
# Epoch  5, CIFAR-10 Batch 1:  Cost: 2.63     Valid Accuracy: 0.279
# Epoch  5, CIFAR-10 Batch 2:  Cost: 2.4      Valid Accuracy: 0.307
# Epoch  5, CIFAR-10 Batch 3:  Cost: 2.27     Valid Accuracy: 0.298
# Epoch  5, CIFAR-10 Batch 4:  Cost: 2.18     Valid Accuracy: 0.29
# Epoch  5, CIFAR-10 Batch 5:  Cost: 2.25     Valid Accuracy: 0.279
# Epoch  6, CIFAR-10 Batch 1:  Cost: 2.23     Valid Accuracy: 0.287
# Epoch  6, CIFAR-10 Batch 2:  Cost: 2.83     Valid Accuracy: 0.267
# Epoch  6, CIFAR-10 Batch 3:  Cost: 2.08     Valid Accuracy: 0.303
# Epoch  6, CIFAR-10 Batch 4:  Cost: 1.99     Valid Accuracy: 0.302
# Epoch  6, CIFAR-10 Batch 5:  Cost: 2.13     Valid Accuracy: 0.299
# Epoch  7, CIFAR-10 Batch 1:  Cost: 2.02     Valid Accuracy: 0.32
# Epoch  7, CIFAR-10 Batch 2:  Cost: 1.84     Valid Accuracy: 0.31
# Epoch  7, CIFAR-10 Batch 3:  Cost: 1.78     Valid Accuracy: 0.307
# Epoch  7, CIFAR-10 Batch 4:  Cost: 1.9      Valid Accuracy: 0.319
# Epoch  7, CIFAR-10 Batch 5:  Cost: 1.82     Valid Accuracy: 0.31
# Epoch  8, CIFAR-10 Batch 1:  Cost: 1.89     Valid Accuracy: 0.311
# Epoch  8, CIFAR-10 Batch 2:  Cost: 1.78     Valid Accuracy: 0.299
# Epoch  8, CIFAR-10 Batch 3:  Cost: 1.61     Valid Accuracy: 0.335
# Epoch  8, CIFAR-10 Batch 4:  Cost: 1.82     Valid Accuracy: 0.323
# Epoch  8, CIFAR-10 Batch 5:  Cost: 1.76     Valid Accuracy: 0.32
# Epoch  9, CIFAR-10 Batch 1:  Cost: 2.22     Valid Accuracy: 0.312
# Epoch  9, CIFAR-10 Batch 2:  Cost: 1.75     Valid Accuracy: 0.312
# Epoch  9, CIFAR-10 Batch 3:  Cost: 1.58     Valid Accuracy: 0.333
# Epoch  9, CIFAR-10 Batch 4:  Cost: 1.69     Valid Accuracy: 0.341
# Epoch  9, CIFAR-10 Batch 5:  Cost: 1.75     Valid Accuracy: 0.294
# Epoch 10, CIFAR-10 Batch 1:  Cost: 2.31     Valid Accuracy: 0.309
# Epoch 10, CIFAR-10 Batch 2:  Cost: 1.86     Valid Accuracy: 0.318
# Epoch 10, CIFAR-10 Batch 3:  Cost: 1.63     Valid Accuracy: 0.343
# Epoch 10, CIFAR-10 Batch 4:  Cost: 1.6      Valid Accuracy: 0.348
# Epoch 10, CIFAR-10 Batch 5:  Cost: 1.55     Valid Accuracy: 0.345
# Epoch 11, CIFAR-10 Batch 1:  Cost: 1.66     Valid Accuracy: 0.337
# Epoch 11, CIFAR-10 Batch 2:  Cost: 1.58     Valid Accuracy: 0.34
# Epoch 11, CIFAR-10 Batch 3:  Cost: 1.64     Valid Accuracy: 0.319
# Epoch 11, CIFAR-10 Batch 4:  Cost: 1.67     Valid Accuracy: 0.312
# Epoch 11, CIFAR-10 Batch 5:  Cost: 1.65     Valid Accuracy: 0.343
# Epoch 12, CIFAR-10 Batch 1:  Cost: 1.71     Valid Accuracy: 0.341
# Epoch 12, CIFAR-10 Batch 2:  Cost: 2.24     Valid Accuracy: 0.256
# Epoch 12, CIFAR-10 Batch 3:  Cost: 1.92     Valid Accuracy: 0.318
# Epoch 12, CIFAR-10 Batch 4:  Cost: 1.73     Valid Accuracy: 0.32
# Epoch 12, CIFAR-10 Batch 5:  Cost: 1.56     Valid Accuracy: 0.344
# Epoch 13, CIFAR-10 Batch 1:  Cost: 1.61     Valid Accuracy: 0.342
# Epoch 13, CIFAR-10 Batch 2:  Cost: 1.6      Valid Accuracy: 0.314
# Epoch 13, CIFAR-10 Batch 3:  Cost: 1.43     Valid Accuracy: 0.366
# Epoch 13, CIFAR-10 Batch 4:  Cost: 1.56     Valid Accuracy: 0.363
# Epoch 13, CIFAR-10 Batch 5:  Cost: 1.47     Valid Accuracy: 0.372
# Epoch 14, CIFAR-10 Batch 1:  Cost: 1.65     Valid Accuracy: 0.342
# Epoch 14, CIFAR-10 Batch 2:  Cost: 1.68     Valid Accuracy: 0.307
# Epoch 14, CIFAR-10 Batch 3:  Cost: 1.56     Valid Accuracy: 0.341
# Epoch 14, CIFAR-10 Batch 4:  Cost: 1.68     Valid Accuracy: 0.353
# Epoch 14, CIFAR-10 Batch 5:  Cost: 1.48     Valid Accuracy: 0.379
# Epoch 15, CIFAR-10 Batch 1:  Cost: 1.68     Valid Accuracy: 0.327
# Epoch 15, CIFAR-10 Batch 2:  Cost: 1.61     Valid Accuracy: 0.315
# Epoch 15, CIFAR-10 Batch 3:  Cost: 1.45     Valid Accuracy: 0.358
# Epoch 15, CIFAR-10 Batch 4:  Cost: 1.52     Valid Accuracy: 0.364
# Epoch 15, CIFAR-10 Batch 5:  Cost: 1.43     Valid Accuracy: 0.384
# Epoch 16, CIFAR-10 Batch 1:  Cost: 1.59     Valid Accuracy: 0.353
# Epoch 16, CIFAR-10 Batch 2:  Cost: 1.67     Valid Accuracy: 0.315
# Epoch 16, CIFAR-10 Batch 3:  Cost: 1.54     Valid Accuracy: 0.348
# Epoch 16, CIFAR-10 Batch 4:  Cost: 1.62     Valid Accuracy: 0.365
# Epoch 16, CIFAR-10 Batch 5:  Cost: 1.44     Valid Accuracy: 0.392
# Epoch 17, CIFAR-10 Batch 1:  Cost: 1.6      Valid Accuracy: 0.341
# Epoch 17, CIFAR-10 Batch 2:  Cost: 1.51     Valid Accuracy: 0.338
# Epoch 17, CIFAR-10 Batch 3:  Cost: 1.42     Valid Accuracy: 0.357
# Epoch 17, CIFAR-10 Batch 4:  Cost: 1.54     Valid Accuracy: 0.36
# Epoch 17, CIFAR-10 Batch 5:  Cost: 1.41     Valid Accuracy: 0.37
# Epoch 18, CIFAR-10 Batch 1:  Cost: 1.55     Valid Accuracy: 0.359
# Epoch 18, CIFAR-10 Batch 2:  Cost: 1.62     Valid Accuracy: 0.324
# Epoch 18, CIFAR-10 Batch 3:  Cost: 1.5      Valid Accuracy: 0.361
# Epoch 18, CIFAR-10 Batch 4:  Cost: 1.56     Valid Accuracy: 0.378
# Epoch 18, CIFAR-10 Batch 5:  Cost: 1.43     Valid Accuracy: 0.383
# Epoch 19, CIFAR-10 Batch 1:  Cost: 1.55     Valid Accuracy: 0.35
# Epoch 19, CIFAR-10 Batch 2:  Cost: 1.48     Valid Accuracy: 0.345
# Epoch 19, CIFAR-10 Batch 3:  Cost: 1.4      Valid Accuracy: 0.36
# Epoch 19, CIFAR-10 Batch 4:  Cost: 1.52     Valid Accuracy: 0.366
# Epoch 19, CIFAR-10 Batch 5:  Cost: 1.4      Valid Accuracy: 0.365
# Epoch 20, CIFAR-10 Batch 1:  Cost: 1.56     Valid Accuracy: 0.357
# Epoch 20, CIFAR-10 Batch 2:  Cost: 1.53     Valid Accuracy: 0.342
# Epoch 20, CIFAR-10 Batch 3:  Cost: 1.39     Valid Accuracy: 0.377
# Epoch 20, CIFAR-10 Batch 4:  Cost: 1.43     Valid Accuracy: 0.389
# Epoch 20, CIFAR-10 Batch 5:  Cost: 1.37     Valid Accuracy: 0.404
# Epoch 21, CIFAR-10 Batch 1:  Cost: 1.54     Valid Accuracy: 0.366
# Epoch 21, CIFAR-10 Batch 2:  Cost: 1.52     Valid Accuracy: 0.339
# Epoch 21, CIFAR-10 Batch 3:  Cost: 1.36     Valid Accuracy: 0.376
# Epoch 21, CIFAR-10 Batch 4:  Cost: 1.45     Valid Accuracy: 0.371
# Epoch 21, CIFAR-10 Batch 5:  Cost: 1.36     Valid Accuracy: 0.399
# Epoch 22, CIFAR-10 Batch 1:  Cost: 1.5      Valid Accuracy: 0.375
# Epoch 22, CIFAR-10 Batch 2:  Cost: 1.61     Valid Accuracy: 0.331
# Epoch 22, CIFAR-10 Batch 3:  Cost: 1.42     Valid Accuracy: 0.384
# Epoch 22, CIFAR-10 Batch 4:  Cost: 1.45     Valid Accuracy: 0.39
# Epoch 22, CIFAR-10 Batch 5:  Cost: 1.37     Valid Accuracy: 0.405
# Epoch 23, CIFAR-10 Batch 1:  Cost: 1.53     Valid Accuracy: 0.364
# Epoch 23, CIFAR-10 Batch 2:  Cost: 1.45     Valid Accuracy: 0.367
# Epoch 23, CIFAR-10 Batch 3:  Cost: 1.31     Valid Accuracy: 0.395
# Epoch 23, CIFAR-10 Batch 4:  Cost: 1.39     Valid Accuracy: 0.391
# Epoch 23, CIFAR-10 Batch 5:  Cost: 1.34     Valid Accuracy: 0.415
# Epoch 24, CIFAR-10 Batch 1:  Cost: 1.47     Valid Accuracy: 0.377
# Epoch 24, CIFAR-10 Batch 2:  Cost: 1.59     Valid Accuracy: 0.331
# Epoch 24, CIFAR-10 Batch 3:  Cost: 1.38     Valid Accuracy: 0.391
# Epoch 24, CIFAR-10 Batch 4:  Cost: 1.4      Valid Accuracy: 0.401
# Epoch 24, CIFAR-10 Batch 5:  Cost: 1.34     Valid Accuracy: 0.415
# Epoch 25, CIFAR-10 Batch 1:  Cost: 1.5      Valid Accuracy: 0.373
# Epoch 25, CIFAR-10 Batch 2:  Cost: 1.47     Valid Accuracy: 0.357
# Epoch 25, CIFAR-10 Batch 3:  Cost: 1.3      Valid Accuracy: 0.399
# Epoch 25, CIFAR-10 Batch 4:  Cost: 1.39     Valid Accuracy: 0.391
# Epoch 25, CIFAR-10 Batch 5:  Cost: 1.33     Valid Accuracy: 0.416
# Epoch 26, CIFAR-10 Batch 1:  Cost: 1.47     Valid Accuracy: 0.379
# Epoch 26, CIFAR-10 Batch 2:  Cost: 1.55     Valid Accuracy: 0.341
# Epoch 26, CIFAR-10 Batch 3:  Cost: 1.33     Valid Accuracy: 0.4
# Epoch 26, CIFAR-10 Batch 4:  Cost: 1.37     Valid Accuracy: 0.4
# Epoch 26, CIFAR-10 Batch 5:  Cost: 1.32     Valid Accuracy: 0.411
# Epoch 27, CIFAR-10 Batch 1:  Cost: 1.49     Valid Accuracy: 0.377
# Epoch 27, CIFAR-10 Batch 2:  Cost: 1.44     Valid Accuracy: 0.365
# Epoch 27, CIFAR-10 Batch 3:  Cost: 1.28     Valid Accuracy: 0.41
# Epoch 27, CIFAR-10 Batch 4:  Cost: 1.36     Valid Accuracy: 0.409
# Epoch 27, CIFAR-10 Batch 5:  Cost: 1.31     Valid Accuracy: 0.416
# Epoch 28, CIFAR-10 Batch 1:  Cost: 1.46     Valid Accuracy: 0.382
# Epoch 28, CIFAR-10 Batch 2:  Cost: 1.5      Valid Accuracy: 0.349
# Epoch 28, CIFAR-10 Batch 3:  Cost: 1.28     Valid Accuracy: 0.41
# Epoch 28, CIFAR-10 Batch 4:  Cost: 1.36     Valid Accuracy: 0.403
# Epoch 28, CIFAR-10 Batch 5:  Cost: 1.31     Valid Accuracy: 0.411
# Epoch 29, CIFAR-10 Batch 1:  Cost: 1.47     Valid Accuracy: 0.379
# Epoch 29, CIFAR-10 Batch 2:  Cost: 1.43     Valid Accuracy: 0.367
# Epoch 29, CIFAR-10 Batch 3:  Cost: 1.26     Valid Accuracy: 0.415
# Epoch 29, CIFAR-10 Batch 4:  Cost: 1.34     Valid Accuracy: 0.409
# Epoch 29, CIFAR-10 Batch 5:  Cost: 1.3      Valid Accuracy: 0.417
# Epoch 30, CIFAR-10 Batch 1:  Cost: 1.45     Valid Accuracy: 0.382
# Epoch 30, CIFAR-10 Batch 2:  Cost: 1.48     Valid Accuracy: 0.353
# Epoch 30, CIFAR-10 Batch 3:  Cost: 1.26     Valid Accuracy: 0.418
# Epoch 30, CIFAR-10 Batch 4:  Cost: 1.34     Valid Accuracy: 0.409
# Epoch 30, CIFAR-10 Batch 5:  Cost: 1.3      Valid Accuracy: 0.417
# Epoch 31, CIFAR-10 Batch 1:  Cost: 1.46     Valid Accuracy: 0.382
# Epoch 31, CIFAR-10 Batch 2:  Cost: 1.4      Valid Accuracy: 0.382
# Epoch 31, CIFAR-10 Batch 3:  Cost: 1.24     Valid Accuracy: 0.424
# Epoch 31, CIFAR-10 Batch 4:  Cost: 1.33     Valid Accuracy: 0.415
# Epoch 31, CIFAR-10 Batch 5:  Cost: 1.29     Valid Accuracy: 0.422
# Epoch 32, CIFAR-10 Batch 1:  Cost: 1.44     Valid Accuracy: 0.382
# Epoch 32, CIFAR-10 Batch 2:  Cost: 1.44     Valid Accuracy: 0.366
# Epoch 32, CIFAR-10 Batch 3:  Cost: 1.24     Valid Accuracy: 0.422
# Epoch 32, CIFAR-10 Batch 4:  Cost: 1.33     Valid Accuracy: 0.411
# Epoch 32, CIFAR-10 Batch 5:  Cost: 1.29     Valid Accuracy: 0.421
# Epoch 33, CIFAR-10 Batch 1:  Cost: 1.45     Valid Accuracy: 0.382
# Epoch 33, CIFAR-10 Batch 2:  Cost: 1.39     Valid Accuracy: 0.39
# Epoch 33, CIFAR-10 Batch 3:  Cost: 1.23     Valid Accuracy: 0.43
# Epoch 33, CIFAR-10 Batch 4:  Cost: 1.31     Valid Accuracy: 0.422
# Epoch 33, CIFAR-10 Batch 5:  Cost: 1.28     Valid Accuracy: 0.431
# Epoch 34, CIFAR-10 Batch 1:  Cost: 1.43     Valid Accuracy: 0.384
# Epoch 34, CIFAR-10 Batch 2:  Cost: 1.41     Valid Accuracy: 0.376
# Epoch 34, CIFAR-10 Batch 3:  Cost: 1.22     Valid Accuracy: 0.428
# Epoch 34, CIFAR-10 Batch 4:  Cost: 1.32     Valid Accuracy: 0.418
# Epoch 34, CIFAR-10 Batch 5:  Cost: 1.28     Valid Accuracy: 0.429
# Epoch 35, CIFAR-10 Batch 1:  Cost: 1.44     Valid Accuracy: 0.385
# Epoch 35, CIFAR-10 Batch 2:  Cost: 1.37     Valid Accuracy: 0.399
# Epoch 35, CIFAR-10 Batch 3:  Cost: 1.21     Valid Accuracy: 0.438
# Epoch 35, CIFAR-10 Batch 4:  Cost: 1.3      Valid Accuracy: 0.427
# Epoch 35, CIFAR-10 Batch 5:  Cost: 1.27     Valid Accuracy: 0.433
# Epoch 36, CIFAR-10 Batch 1:  Cost: 1.42     Valid Accuracy: 0.385
# Epoch 36, CIFAR-10 Batch 2:  Cost: 1.38     Valid Accuracy: 0.392
# Epoch 36, CIFAR-10 Batch 3:  Cost: 1.21     Valid Accuracy: 0.441
# Epoch 36, CIFAR-10 Batch 4:  Cost: 1.3      Valid Accuracy: 0.426
# Epoch 36, CIFAR-10 Batch 5:  Cost: 1.27     Valid Accuracy: 0.436
# Epoch 37, CIFAR-10 Batch 1:  Cost: 1.42     Valid Accuracy: 0.387
# Epoch 37, CIFAR-10 Batch 2:  Cost: 1.36     Valid Accuracy: 0.401
# Epoch 37, CIFAR-10 Batch 3:  Cost: 1.2      Valid Accuracy: 0.442
# Epoch 37, CIFAR-10 Batch 4:  Cost: 1.29     Valid Accuracy: 0.431
# Epoch 37, CIFAR-10 Batch 5:  Cost: 1.26     Valid Accuracy: 0.439
# Epoch 38, CIFAR-10 Batch 1:  Cost: 1.41     Valid Accuracy: 0.387
# Epoch 38, CIFAR-10 Batch 2:  Cost: 1.36     Valid Accuracy: 0.401
# Epoch 38, CIFAR-10 Batch 3:  Cost: 1.19     Valid Accuracy: 0.445
# Epoch 38, CIFAR-10 Batch 4:  Cost: 1.28     Valid Accuracy: 0.432
# Epoch 38, CIFAR-10 Batch 5:  Cost: 1.25     Valid Accuracy: 0.441
# Epoch 39, CIFAR-10 Batch 1:  Cost: 1.41     Valid Accuracy: 0.39
# Epoch 39, CIFAR-10 Batch 2:  Cost: 1.34     Valid Accuracy: 0.409
# Epoch 39, CIFAR-10 Batch 3:  Cost: 1.19     Valid Accuracy: 0.446
# Epoch 39, CIFAR-10 Batch 4:  Cost: 1.27     Valid Accuracy: 0.438
# Epoch 39, CIFAR-10 Batch 5:  Cost: 1.25     Valid Accuracy: 0.446
# Epoch 40, CIFAR-10 Batch 1:  Cost: 1.41     Valid Accuracy: 0.391
# Epoch 40, CIFAR-10 Batch 2:  Cost: 1.34     Valid Accuracy: 0.409
# Epoch 40, CIFAR-10 Batch 3:  Cost: 1.18     Valid Accuracy: 0.449
# Epoch 40, CIFAR-10 Batch 4:  Cost: 1.27     Valid Accuracy: 0.438
# Epoch 40, CIFAR-10 Batch 5:  Cost: 1.24     Valid Accuracy: 0.445
# Epoch 41, CIFAR-10 Batch 1:  Cost: 1.4      Valid Accuracy: 0.391
# Epoch 41, CIFAR-10 Batch 2:  Cost: 1.33     Valid Accuracy: 0.42
# Epoch 41, CIFAR-10 Batch 3:  Cost: 1.18     Valid Accuracy: 0.455
# Epoch 41, CIFAR-10 Batch 4:  Cost: 1.26     Valid Accuracy: 0.444
# Epoch 41, CIFAR-10 Batch 5:  Cost: 1.24     Valid Accuracy: 0.448
# Epoch 42, CIFAR-10 Batch 1:  Cost: 1.4      Valid Accuracy: 0.393
# Epoch 42, CIFAR-10 Batch 2:  Cost: 1.33     Valid Accuracy: 0.418
# Epoch 42, CIFAR-10 Batch 3:  Cost: 1.17     Valid Accuracy: 0.456
# Epoch 42, CIFAR-10 Batch 4:  Cost: 1.26     Valid Accuracy: 0.442
# Epoch 42, CIFAR-10 Batch 5:  Cost: 1.23     Valid Accuracy: 0.446
# Epoch 43, CIFAR-10 Batch 1:  Cost: 1.4      Valid Accuracy: 0.393
# Epoch 43, CIFAR-10 Batch 2:  Cost: 1.31     Valid Accuracy: 0.43
# Epoch 43, CIFAR-10 Batch 3:  Cost: 1.17     Valid Accuracy: 0.458
# Epoch 43, CIFAR-10 Batch 4:  Cost: 1.25     Valid Accuracy: 0.449
# Epoch 43, CIFAR-10 Batch 5:  Cost: 1.23     Valid Accuracy: 0.45
# Epoch 44, CIFAR-10 Batch 1:  Cost: 1.39     Valid Accuracy: 0.395
# Epoch 44, CIFAR-10 Batch 2:  Cost: 1.31     Valid Accuracy: 0.431
# Epoch 44, CIFAR-10 Batch 3:  Cost: 1.16     Valid Accuracy: 0.461
# Epoch 44, CIFAR-10 Batch 4:  Cost: 1.24     Valid Accuracy: 0.449
# Epoch 44, CIFAR-10 Batch 5:  Cost: 1.22     Valid Accuracy: 0.452
# Epoch 45, CIFAR-10 Batch 1:  Cost: 1.39     Valid Accuracy: 0.397
# Epoch 45, CIFAR-10 Batch 2:  Cost: 1.31     Valid Accuracy: 0.435
# Epoch 45, CIFAR-10 Batch 3:  Cost: 1.16     Valid Accuracy: 0.464
# Epoch 45, CIFAR-10 Batch 4:  Cost: 1.23     Valid Accuracy: 0.451
# Epoch 45, CIFAR-10 Batch 5:  Cost: 1.22     Valid Accuracy: 0.454
# Epoch 46, CIFAR-10 Batch 1:  Cost: 1.38     Valid Accuracy: 0.399
# Epoch 46, CIFAR-10 Batch 2:  Cost: 1.3      Valid Accuracy: 0.438
# Epoch 46, CIFAR-10 Batch 3:  Cost: 1.16     Valid Accuracy: 0.466
# Epoch 46, CIFAR-10 Batch 4:  Cost: 1.23     Valid Accuracy: 0.451
# Epoch 46, CIFAR-10 Batch 5:  Cost: 1.22     Valid Accuracy: 0.453
# Epoch 47, CIFAR-10 Batch 1:  Cost: 1.38     Valid Accuracy: 0.402
# Epoch 47, CIFAR-10 Batch 2:  Cost: 1.3      Valid Accuracy: 0.45
# Epoch 47, CIFAR-10 Batch 3:  Cost: 1.16     Valid Accuracy: 0.465
# Epoch 47, CIFAR-10 Batch 4:  Cost: 1.23     Valid Accuracy: 0.456
# Epoch 47, CIFAR-10 Batch 5:  Cost: 1.21     Valid Accuracy: 0.457
# Epoch 48, CIFAR-10 Batch 1:  Cost: 1.37     Valid Accuracy: 0.405
# Epoch 48, CIFAR-10 Batch 2:  Cost: 1.3      Valid Accuracy: 0.447
# Epoch 48, CIFAR-10 Batch 3:  Cost: 1.17     Valid Accuracy: 0.462
# Epoch 48, CIFAR-10 Batch 4:  Cost: 1.22     Valid Accuracy: 0.455
# Epoch 48, CIFAR-10 Batch 5:  Cost: 1.21     Valid Accuracy: 0.458
# Epoch 49, CIFAR-10 Batch 1:  Cost: 1.36     Valid Accuracy: 0.406
# Epoch 49, CIFAR-10 Batch 2:  Cost: 1.33     Valid Accuracy: 0.438
# Epoch 49, CIFAR-10 Batch 3:  Cost: 1.2      Valid Accuracy: 0.458
# Epoch 49, CIFAR-10 Batch 4:  Cost: 1.24     Valid Accuracy: 0.439
# Epoch 49, CIFAR-10 Batch 5:  Cost: 1.23     Valid Accuracy: 0.441
# Epoch 50, CIFAR-10 Batch 1:  Cost: 1.3      Valid Accuracy: 0.428
# Epoch 50, CIFAR-10 Batch 2:  Cost: 1.36     Valid Accuracy: 0.43
# Epoch 50, CIFAR-10 Batch 3:  Cost: 1.14     Valid Accuracy: 0.468
# Epoch 50, CIFAR-10 Batch 4:  Cost: 1.25     Valid Accuracy: 0.425
# Epoch 50, CIFAR-10 Batch 5:  Cost: 1.21     Valid Accuracy: 0.462
# Epoch 51, CIFAR-10 Batch 1:  Cost: 1.28     Valid Accuracy: 0.435
# Epoch 51, CIFAR-10 Batch 2:  Cost: 1.31     Valid Accuracy: 0.437
# Epoch 51, CIFAR-10 Batch 3:  Cost: 1.14     Valid Accuracy: 0.471
# Epoch 51, CIFAR-10 Batch 4:  Cost: 1.24     Valid Accuracy: 0.431
# Epoch 51, CIFAR-10 Batch 5:  Cost: 1.2      Valid Accuracy: 0.463
# Epoch 52, CIFAR-10 Batch 1:  Cost: 1.27     Valid Accuracy: 0.44
# Epoch 52, CIFAR-10 Batch 2:  Cost: 1.3      Valid Accuracy: 0.442
# Epoch 52, CIFAR-10 Batch 3:  Cost: 1.13     Valid Accuracy: 0.469
# Epoch 52, CIFAR-10 Batch 4:  Cost: 1.23     Valid Accuracy: 0.435
# Epoch 52, CIFAR-10 Batch 5:  Cost: 1.2      Valid Accuracy: 0.465
# Epoch 53, CIFAR-10 Batch 1:  Cost: 1.27     Valid Accuracy: 0.441
# Epoch 53, CIFAR-10 Batch 2:  Cost: 1.29     Valid Accuracy: 0.445
# Epoch 53, CIFAR-10 Batch 3:  Cost: 1.13     Valid Accuracy: 0.471
# Epoch 53, CIFAR-10 Batch 4:  Cost: 1.23     Valid Accuracy: 0.437
# Epoch 53, CIFAR-10 Batch 5:  Cost: 1.19     Valid Accuracy: 0.465
# Epoch 54, CIFAR-10 Batch 1:  Cost: 1.26     Valid Accuracy: 0.442
# Epoch 54, CIFAR-10 Batch 2:  Cost: 1.28     Valid Accuracy: 0.449
# Epoch 54, CIFAR-10 Batch 3:  Cost: 1.12     Valid Accuracy: 0.473
# Epoch 54, CIFAR-10 Batch 4:  Cost: 1.22     Valid Accuracy: 0.44
# Epoch 54, CIFAR-10 Batch 5:  Cost: 1.19     Valid Accuracy: 0.465
# Epoch 55, CIFAR-10 Batch 1:  Cost: 1.26     Valid Accuracy: 0.444
# Epoch 55, CIFAR-10 Batch 2:  Cost: 1.28     Valid Accuracy: 0.45
# Epoch 55, CIFAR-10 Batch 3:  Cost: 1.12     Valid Accuracy: 0.473
# Epoch 55, CIFAR-10 Batch 4:  Cost: 1.22     Valid Accuracy: 0.44
# Epoch 55, CIFAR-10 Batch 5:  Cost: 1.19     Valid Accuracy: 0.469
# Epoch 56, CIFAR-10 Batch 1:  Cost: 1.26     Valid Accuracy: 0.444
# Epoch 56, CIFAR-10 Batch 2:  Cost: 1.27     Valid Accuracy: 0.454
# Epoch 56, CIFAR-10 Batch 3:  Cost: 1.12     Valid Accuracy: 0.474
# Epoch 56, CIFAR-10 Batch 4:  Cost: 1.21     Valid Accuracy: 0.441
# Epoch 56, CIFAR-10 Batch 5:  Cost: 1.18     Valid Accuracy: 0.471
# Epoch 57, CIFAR-10 Batch 1:  Cost: 1.25     Valid Accuracy: 0.446
# Epoch 57, CIFAR-10 Batch 2:  Cost: 1.27     Valid Accuracy: 0.455
# Epoch 57, CIFAR-10 Batch 3:  Cost: 1.11     Valid Accuracy: 0.475
# Epoch 57, CIFAR-10 Batch 4:  Cost: 1.21     Valid Accuracy: 0.441
# Epoch 57, CIFAR-10 Batch 5:  Cost: 1.18     Valid Accuracy: 0.473
# Epoch 58, CIFAR-10 Batch 1:  Cost: 1.25     Valid Accuracy: 0.448
# Epoch 58, CIFAR-10 Batch 2:  Cost: 1.26     Valid Accuracy: 0.455
# Epoch 58, CIFAR-10 Batch 3:  Cost: 1.11     Valid Accuracy: 0.476
# Epoch 58, CIFAR-10 Batch 4:  Cost: 1.2      Valid Accuracy: 0.444
# Epoch 58, CIFAR-10 Batch 5:  Cost: 1.17     Valid Accuracy: 0.473
# Epoch 59, CIFAR-10 Batch 1:  Cost: 1.25     Valid Accuracy: 0.448
# Epoch 59, CIFAR-10 Batch 2:  Cost: 1.25     Valid Accuracy: 0.458
# Epoch 59, CIFAR-10 Batch 3:  Cost: 1.1      Valid Accuracy: 0.476
# Epoch 59, CIFAR-10 Batch 4:  Cost: 1.2      Valid Accuracy: 0.446
# Epoch 59, CIFAR-10 Batch 5:  Cost: 1.17     Valid Accuracy: 0.473
# Epoch 60, CIFAR-10 Batch 1:  Cost: 1.24     Valid Accuracy: 0.449
# Epoch 60, CIFAR-10 Batch 2:  Cost: 1.25     Valid Accuracy: 0.458
# Epoch 60, CIFAR-10 Batch 3:  Cost: 1.1      Valid Accuracy: 0.478
# Epoch 60, CIFAR-10 Batch 4:  Cost: 1.2      Valid Accuracy: 0.449
# Epoch 60, CIFAR-10 Batch 5:  Cost: 1.16     Valid Accuracy: 0.473
# Epoch 61, CIFAR-10 Batch 1:  Cost: 1.24     Valid Accuracy: 0.449
# Epoch 61, CIFAR-10 Batch 2:  Cost: 1.24     Valid Accuracy: 0.46
# Epoch 61, CIFAR-10 Batch 3:  Cost: 1.1      Valid Accuracy: 0.477
# Epoch 61, CIFAR-10 Batch 4:  Cost: 1.19     Valid Accuracy: 0.452
# Epoch 61, CIFAR-10 Batch 5:  Cost: 1.16     Valid Accuracy: 0.475
# Epoch 62, CIFAR-10 Batch 1:  Cost: 1.24     Valid Accuracy: 0.449
# Epoch 62, CIFAR-10 Batch 2:  Cost: 1.24     Valid Accuracy: 0.459
# Epoch 62, CIFAR-10 Batch 3:  Cost: 1.09     Valid Accuracy: 0.48
# Epoch 62, CIFAR-10 Batch 4:  Cost: 1.19     Valid Accuracy: 0.451
# Epoch 62, CIFAR-10 Batch 5:  Cost: 1.15     Valid Accuracy: 0.473
# Epoch 63, CIFAR-10 Batch 1:  Cost: 1.23     Valid Accuracy: 0.449
# Epoch 63, CIFAR-10 Batch 2:  Cost: 1.23     Valid Accuracy: 0.463
# Epoch 63, CIFAR-10 Batch 3:  Cost: 1.09     Valid Accuracy: 0.484
# Epoch 63, CIFAR-10 Batch 4:  Cost: 1.18     Valid Accuracy: 0.456
# Epoch 63, CIFAR-10 Batch 5:  Cost: 1.15     Valid Accuracy: 0.476
# Epoch 64, CIFAR-10 Batch 1:  Cost: 1.23     Valid Accuracy: 0.452
# Epoch 64, CIFAR-10 Batch 2:  Cost: 1.22     Valid Accuracy: 0.468
# Epoch 64, CIFAR-10 Batch 3:  Cost: 1.09     Valid Accuracy: 0.485
# Epoch 64, CIFAR-10 Batch 4:  Cost: 1.18     Valid Accuracy: 0.457
# Epoch 64, CIFAR-10 Batch 5:  Cost: 1.15     Valid Accuracy: 0.478
# Epoch 65, CIFAR-10 Batch 1:  Cost: 1.23     Valid Accuracy: 0.453
# Epoch 65, CIFAR-10 Batch 2:  Cost: 1.22     Valid Accuracy: 0.469
# Epoch 65, CIFAR-10 Batch 3:  Cost: 1.08     Valid Accuracy: 0.485
# Epoch 65, CIFAR-10 Batch 4:  Cost: 1.18     Valid Accuracy: 0.459
# Epoch 65, CIFAR-10 Batch 5:  Cost: 1.14     Valid Accuracy: 0.477
# Epoch 66, CIFAR-10 Batch 1:  Cost: 1.22     Valid Accuracy: 0.455
# Epoch 66, CIFAR-10 Batch 2:  Cost: 1.21     Valid Accuracy: 0.471
# Epoch 66, CIFAR-10 Batch 3:  Cost: 1.08     Valid Accuracy: 0.486
# Epoch 66, CIFAR-10 Batch 4:  Cost: 1.17     Valid Accuracy: 0.461
# Epoch 66, CIFAR-10 Batch 5:  Cost: 1.14     Valid Accuracy: 0.479
# Epoch 67, CIFAR-10 Batch 1:  Cost: 1.22     Valid Accuracy: 0.458
# Epoch 67, CIFAR-10 Batch 2:  Cost: 1.2      Valid Accuracy: 0.474
# Epoch 67, CIFAR-10 Batch 3:  Cost: 1.08     Valid Accuracy: 0.488
# Epoch 67, CIFAR-10 Batch 4:  Cost: 1.17     Valid Accuracy: 0.462
# Epoch 67, CIFAR-10 Batch 5:  Cost: 1.13     Valid Accuracy: 0.481
# Epoch 68, CIFAR-10 Batch 1:  Cost: 1.21     Valid Accuracy: 0.459
# Epoch 68, CIFAR-10 Batch 2:  Cost: 1.2      Valid Accuracy: 0.477
# Epoch 68, CIFAR-10 Batch 3:  Cost: 1.07     Valid Accuracy: 0.491
# Epoch 68, CIFAR-10 Batch 4:  Cost: 1.16     Valid Accuracy: 0.464
# Epoch 68, CIFAR-10 Batch 5:  Cost: 1.13     Valid Accuracy: 0.481
# Epoch 69, CIFAR-10 Batch 1:  Cost: 1.21     Valid Accuracy: 0.461
# Epoch 69, CIFAR-10 Batch 2:  Cost: 1.19     Valid Accuracy: 0.477
# Epoch 69, CIFAR-10 Batch 3:  Cost: 1.07     Valid Accuracy: 0.491
# Epoch 69, CIFAR-10 Batch 4:  Cost: 1.16     Valid Accuracy: 0.467
# Epoch 69, CIFAR-10 Batch 5:  Cost: 1.13     Valid Accuracy: 0.48
# Epoch 70, CIFAR-10 Batch 1:  Cost: 1.21     Valid Accuracy: 0.463
# Epoch 70, CIFAR-10 Batch 2:  Cost: 1.19     Valid Accuracy: 0.48
# Epoch 70, CIFAR-10 Batch 3:  Cost: 1.07     Valid Accuracy: 0.492
# Epoch 70, CIFAR-10 Batch 4:  Cost: 1.15     Valid Accuracy: 0.469
# Epoch 70, CIFAR-10 Batch 5:  Cost: 1.13     Valid Accuracy: 0.484
# Epoch 71, CIFAR-10 Batch 1:  Cost: 1.2      Valid Accuracy: 0.464
# Epoch 71, CIFAR-10 Batch 2:  Cost: 1.18     Valid Accuracy: 0.482
# Epoch 71, CIFAR-10 Batch 3:  Cost: 1.06     Valid Accuracy: 0.493
# Epoch 71, CIFAR-10 Batch 4:  Cost: 1.14     Valid Accuracy: 0.473
# Epoch 71, CIFAR-10 Batch 5:  Cost: 1.12     Valid Accuracy: 0.486
# Epoch 72, CIFAR-10 Batch 1:  Cost: 1.2      Valid Accuracy: 0.465
# Epoch 72, CIFAR-10 Batch 2:  Cost: 1.18     Valid Accuracy: 0.488
# Epoch 72, CIFAR-10 Batch 3:  Cost: 1.06     Valid Accuracy: 0.495
# Epoch 72, CIFAR-10 Batch 4:  Cost: 1.14     Valid Accuracy: 0.475
# Epoch 72, CIFAR-10 Batch 5:  Cost: 1.12     Valid Accuracy: 0.485
# Epoch 73, CIFAR-10 Batch 1:  Cost: 1.19     Valid Accuracy: 0.47
# Epoch 73, CIFAR-10 Batch 2:  Cost: 1.17     Valid Accuracy: 0.491
# Epoch 73, CIFAR-10 Batch 3:  Cost: 1.05     Valid Accuracy: 0.496
# Epoch 73, CIFAR-10 Batch 4:  Cost: 1.13     Valid Accuracy: 0.475
# Epoch 73, CIFAR-10 Batch 5:  Cost: 1.12     Valid Accuracy: 0.487
# Epoch 74, CIFAR-10 Batch 1:  Cost: 1.19     Valid Accuracy: 0.471
# Epoch 74, CIFAR-10 Batch 2:  Cost: 1.17     Valid Accuracy: 0.495
# Epoch 74, CIFAR-10 Batch 3:  Cost: 1.05     Valid Accuracy: 0.496
# Epoch 74, CIFAR-10 Batch 4:  Cost: 1.12     Valid Accuracy: 0.478
# Epoch 74, CIFAR-10 Batch 5:  Cost: 1.12     Valid Accuracy: 0.488
# Epoch 75, CIFAR-10 Batch 1:  Cost: 1.18     Valid Accuracy: 0.473
# Epoch 75, CIFAR-10 Batch 2:  Cost: 1.16     Valid Accuracy: 0.496
# Epoch 75, CIFAR-10 Batch 3:  Cost: 1.05     Valid Accuracy: 0.497
# Epoch 75, CIFAR-10 Batch 4:  Cost: 1.12     Valid Accuracy: 0.483
# Epoch 75, CIFAR-10 Batch 5:  Cost: 1.12     Valid Accuracy: 0.488
# Epoch 76, CIFAR-10 Batch 1:  Cost: 1.18     Valid Accuracy: 0.476
# Epoch 76, CIFAR-10 Batch 2:  Cost: 1.16     Valid Accuracy: 0.495
# Epoch 76, CIFAR-10 Batch 3:  Cost: 1.04     Valid Accuracy: 0.5
# Epoch 76, CIFAR-10 Batch 4:  Cost: 1.12     Valid Accuracy: 0.483
# Epoch 76, CIFAR-10 Batch 5:  Cost: 1.11     Valid Accuracy: 0.49
# Epoch 77, CIFAR-10 Batch 1:  Cost: 1.17     Valid Accuracy: 0.48
# Epoch 77, CIFAR-10 Batch 2:  Cost: 1.15     Valid Accuracy: 0.497
# Epoch 77, CIFAR-10 Batch 3:  Cost: 1.04     Valid Accuracy: 0.498
# Epoch 77, CIFAR-10 Batch 4:  Cost: 1.11     Valid Accuracy: 0.483
# Epoch 77, CIFAR-10 Batch 5:  Cost: 1.11     Valid Accuracy: 0.49
# Epoch 78, CIFAR-10 Batch 1:  Cost: 1.17     Valid Accuracy: 0.481
# Epoch 78, CIFAR-10 Batch 2:  Cost: 1.15     Valid Accuracy: 0.501
# Epoch 78, CIFAR-10 Batch 3:  Cost: 1.04     Valid Accuracy: 0.499
# Epoch 78, CIFAR-10 Batch 4:  Cost: 1.1      Valid Accuracy: 0.485
# Epoch 78, CIFAR-10 Batch 5:  Cost: 1.1      Valid Accuracy: 0.492
# Epoch 79, CIFAR-10 Batch 1:  Cost: 1.16     Valid Accuracy: 0.483
# Epoch 79, CIFAR-10 Batch 2:  Cost: 1.14     Valid Accuracy: 0.499
# Epoch 79, CIFAR-10 Batch 3:  Cost: 1.04     Valid Accuracy: 0.5
# Epoch 79, CIFAR-10 Batch 4:  Cost: 1.1      Valid Accuracy: 0.486
# Epoch 79, CIFAR-10 Batch 5:  Cost: 1.1      Valid Accuracy: 0.493
# Epoch 80, CIFAR-10 Batch 1:  Cost: 1.16     Valid Accuracy: 0.486
# Epoch 80, CIFAR-10 Batch 2:  Cost: 1.14     Valid Accuracy: 0.502
# Epoch 80, CIFAR-10 Batch 3:  Cost: 1.03     Valid Accuracy: 0.5
# Epoch 80, CIFAR-10 Batch 4:  Cost: 1.1      Valid Accuracy: 0.488
# Epoch 80, CIFAR-10 Batch 5:  Cost: 1.1      Valid Accuracy: 0.495
# Epoch 81, CIFAR-10 Batch 1:  Cost: 1.16     Valid Accuracy: 0.489
# Epoch 81, CIFAR-10 Batch 2:  Cost: 1.13     Valid Accuracy: 0.502
# Epoch 81, CIFAR-10 Batch 3:  Cost: 1.03     Valid Accuracy: 0.501
# Epoch 81, CIFAR-10 Batch 4:  Cost: 1.09     Valid Accuracy: 0.493
# Epoch 81, CIFAR-10 Batch 5:  Cost: 1.1      Valid Accuracy: 0.497
# Epoch 82, CIFAR-10 Batch 1:  Cost: 1.15     Valid Accuracy: 0.491
# Epoch 82, CIFAR-10 Batch 2:  Cost: 1.13     Valid Accuracy: 0.504
# Epoch 82, CIFAR-10 Batch 3:  Cost: 1.03     Valid Accuracy: 0.501
# Epoch 82, CIFAR-10 Batch 4:  Cost: 1.09     Valid Accuracy: 0.492
# Epoch 82, CIFAR-10 Batch 5:  Cost: 1.1      Valid Accuracy: 0.498
# Epoch 83, CIFAR-10 Batch 1:  Cost: 1.15     Valid Accuracy: 0.494
# Epoch 83, CIFAR-10 Batch 2:  Cost: 1.12     Valid Accuracy: 0.504
# Epoch 83, CIFAR-10 Batch 3:  Cost: 1.03     Valid Accuracy: 0.502
# Epoch 83, CIFAR-10 Batch 4:  Cost: 1.09     Valid Accuracy: 0.489
# Epoch 83, CIFAR-10 Batch 5:  Cost: 1.09     Valid Accuracy: 0.499
# Epoch 84, CIFAR-10 Batch 1:  Cost: 1.14     Valid Accuracy: 0.494
# Epoch 84, CIFAR-10 Batch 2:  Cost: 1.12     Valid Accuracy: 0.507
# Epoch 84, CIFAR-10 Batch 3:  Cost: 1.02     Valid Accuracy: 0.499
# Epoch 84, CIFAR-10 Batch 4:  Cost: 1.08     Valid Accuracy: 0.491
# Epoch 84, CIFAR-10 Batch 5:  Cost: 1.09     Valid Accuracy: 0.501
# Epoch 85, CIFAR-10 Batch 1:  Cost: 1.14     Valid Accuracy: 0.495
# Epoch 85, CIFAR-10 Batch 2:  Cost: 1.12     Valid Accuracy: 0.508
# Epoch 85, CIFAR-10 Batch 3:  Cost: 1.02     Valid Accuracy: 0.503
# Epoch 85, CIFAR-10 Batch 4:  Cost: 1.08     Valid Accuracy: 0.493
# Epoch 85, CIFAR-10 Batch 5:  Cost: 1.08     Valid Accuracy: 0.502
# Epoch 86, CIFAR-10 Batch 1:  Cost: 1.14     Valid Accuracy: 0.497
# Epoch 86, CIFAR-10 Batch 2:  Cost: 1.11     Valid Accuracy: 0.508
# Epoch 86, CIFAR-10 Batch 3:  Cost: 1.02     Valid Accuracy: 0.503
# Epoch 86, CIFAR-10 Batch 4:  Cost: 1.08     Valid Accuracy: 0.491
# Epoch 86, CIFAR-10 Batch 5:  Cost: 1.08     Valid Accuracy: 0.503
# Epoch 87, CIFAR-10 Batch 1:  Cost: 1.14     Valid Accuracy: 0.496
# Epoch 87, CIFAR-10 Batch 2:  Cost: 1.11     Valid Accuracy: 0.512
# Epoch 87, CIFAR-10 Batch 3:  Cost: 1.02     Valid Accuracy: 0.504
# Epoch 87, CIFAR-10 Batch 4:  Cost: 1.08     Valid Accuracy: 0.488
# Epoch 87, CIFAR-10 Batch 5:  Cost: 1.08     Valid Accuracy: 0.504
# Epoch 88, CIFAR-10 Batch 1:  Cost: 1.14     Valid Accuracy: 0.491
# Epoch 88, CIFAR-10 Batch 2:  Cost: 1.11     Valid Accuracy: 0.512
# Epoch 88, CIFAR-10 Batch 3:  Cost: 1.03     Valid Accuracy: 0.506
# Epoch 88, CIFAR-10 Batch 4:  Cost: 1.09     Valid Accuracy: 0.48
# Epoch 88, CIFAR-10 Batch 5:  Cost: 1.08     Valid Accuracy: 0.507
# Epoch 89, CIFAR-10 Batch 1:  Cost: 1.14     Valid Accuracy: 0.488
# Epoch 89, CIFAR-10 Batch 2:  Cost: 1.1      Valid Accuracy: 0.513
# Epoch 89, CIFAR-10 Batch 3:  Cost: 1.06     Valid Accuracy: 0.496
# Epoch 89, CIFAR-10 Batch 4:  Cost: 1.11     Valid Accuracy: 0.47
# Epoch 89, CIFAR-10 Batch 5:  Cost: 1.08     Valid Accuracy: 0.504
# Epoch 90, CIFAR-10 Batch 1:  Cost: 1.14     Valid Accuracy: 0.499
# Epoch 90, CIFAR-10 Batch 2:  Cost: 1.12     Valid Accuracy: 0.503
# Epoch 90, CIFAR-10 Batch 3:  Cost: 1.11     Valid Accuracy: 0.481
# Epoch 90, CIFAR-10 Batch 4:  Cost: 1.09     Valid Accuracy: 0.495
# Epoch 90, CIFAR-10 Batch 5:  Cost: 1.09     Valid Accuracy: 0.496
# Epoch 91, CIFAR-10 Batch 1:  Cost: 1.12     Valid Accuracy: 0.508
# Epoch 91, CIFAR-10 Batch 2:  Cost: 1.11     Valid Accuracy: 0.501
# Epoch 91, CIFAR-10 Batch 3:  Cost: 1.06     Valid Accuracy: 0.493
# Epoch 91, CIFAR-10 Batch 4:  Cost: 1.07     Valid Accuracy: 0.508
# Epoch 91, CIFAR-10 Batch 5:  Cost: 1.05     Valid Accuracy: 0.509
# Epoch 92, CIFAR-10 Batch 1:  Cost: 1.11     Valid Accuracy: 0.508
# Epoch 92, CIFAR-10 Batch 2:  Cost: 1.12     Valid Accuracy: 0.485
# Epoch 92, CIFAR-10 Batch 3:  Cost: 1.02     Valid Accuracy: 0.507
# Epoch 92, CIFAR-10 Batch 4:  Cost: 1.07     Valid Accuracy: 0.511
# Epoch 92, CIFAR-10 Batch 5:  Cost: 1.04     Valid Accuracy: 0.511
# Epoch 93, CIFAR-10 Batch 1:  Cost: 1.1      Valid Accuracy: 0.509
# Epoch 93, CIFAR-10 Batch 2:  Cost: 1.15     Valid Accuracy: 0.47
# Epoch 93, CIFAR-10 Batch 3:  Cost: 0.995    Valid Accuracy: 0.512
# Epoch 93, CIFAR-10 Batch 4:  Cost: 1.05     Valid Accuracy: 0.513
# Epoch 93, CIFAR-10 Batch 5:  Cost: 1.04     Valid Accuracy: 0.519
# Epoch 94, CIFAR-10 Batch 1:  Cost: 1.09     Valid Accuracy: 0.514
# Epoch 94, CIFAR-10 Batch 2:  Cost: 1.15     Valid Accuracy: 0.466
# Epoch 94, CIFAR-10 Batch 3:  Cost: 0.996    Valid Accuracy: 0.504
# Epoch 94, CIFAR-10 Batch 4:  Cost: 1.04     Valid Accuracy: 0.514
# Epoch 94, CIFAR-10 Batch 5:  Cost: 1.03     Valid Accuracy: 0.521
# Epoch 95, CIFAR-10 Batch 1:  Cost: 1.09     Valid Accuracy: 0.515
# Epoch 95, CIFAR-10 Batch 2:  Cost: 1.13     Valid Accuracy: 0.477
# Epoch 95, CIFAR-10 Batch 3:  Cost: 0.992    Valid Accuracy: 0.506
# Epoch 95, CIFAR-10 Batch 4:  Cost: 1.04     Valid Accuracy: 0.517
# Epoch 95, CIFAR-10 Batch 5:  Cost: 1.02     Valid Accuracy: 0.52
# Epoch 96, CIFAR-10 Batch 1:  Cost: 1.08     Valid Accuracy: 0.515
# Epoch 96, CIFAR-10 Batch 2:  Cost: 1.12     Valid Accuracy: 0.482
# Epoch 96, CIFAR-10 Batch 3:  Cost: 0.99     Valid Accuracy: 0.507
# Epoch 96, CIFAR-10 Batch 4:  Cost: 1.04     Valid Accuracy: 0.516
# Epoch 96, CIFAR-10 Batch 5:  Cost: 1.02     Valid Accuracy: 0.522
# Epoch 97, CIFAR-10 Batch 1:  Cost: 1.08     Valid Accuracy: 0.517
# Epoch 97, CIFAR-10 Batch 2:  Cost: 1.11     Valid Accuracy: 0.484
# Epoch 97, CIFAR-10 Batch 3:  Cost: 0.987    Valid Accuracy: 0.507
# Epoch 97, CIFAR-10 Batch 4:  Cost: 1.03     Valid Accuracy: 0.518
# Epoch 97, CIFAR-10 Batch 5:  Cost: 1.02     Valid Accuracy: 0.523
# Epoch 98, CIFAR-10 Batch 1:  Cost: 1.08     Valid Accuracy: 0.518
# Epoch 98, CIFAR-10 Batch 2:  Cost: 1.11     Valid Accuracy: 0.488
# Epoch 98, CIFAR-10 Batch 3:  Cost: 0.986    Valid Accuracy: 0.508
# Epoch 98, CIFAR-10 Batch 4:  Cost: 1.03     Valid Accuracy: 0.519
# Epoch 98, CIFAR-10 Batch 5:  Cost: 1.01     Valid Accuracy: 0.523
# Epoch 99, CIFAR-10 Batch 1:  Cost: 1.07     Valid Accuracy: 0.517
# Epoch 99, CIFAR-10 Batch 2:  Cost: 1.1      Valid Accuracy: 0.491
# Epoch 99, CIFAR-10 Batch 3:  Cost: 0.985    Valid Accuracy: 0.509
# Epoch 99, CIFAR-10 Batch 4:  Cost: 1.03     Valid Accuracy: 0.515
# Epoch 99, CIFAR-10 Batch 5:  Cost: 1.01     Valid Accuracy: 0.523
# Epoch 100, CIFAR-10 Batch 1:  Cost: 1.07     Valid Accuracy: 0.517
# Epoch 100, CIFAR-10 Batch 2:  Cost: 1.09     Valid Accuracy: 0.493
# Epoch 100, CIFAR-10 Batch 3:  Cost: 0.98     Valid Accuracy: 0.511
# Epoch 100, CIFAR-10 Batch 4:  Cost: 1.02     Valid Accuracy: 0.518
# Epoch 100, CIFAR-10 Batch 5:  Cost: 1.01     Valid Accuracy: 0.524

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.5309948980808258

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
